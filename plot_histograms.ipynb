# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.20/04

# %%
oldfile = ROOT.TFile('/data/newhouse/HNL/tests/histos_old/histograms_mc_ueu.root')
c = ROOT.TCanvas()
cutflow = oldfile.Get('VSI/CutFlow/CutFlow_VSI')
cutflow.ls()
c.SetLogy()
cutflow.SetFillColor(ROOT.kAzure-4)
cutflow.SetLineWidth(0)
cutflow.GetYaxis().SetTickLength(0.)
cutflow.SetMarkerSize(2.2)
cutflow.Draw('HIST TEXT35 SAME')
c.Draw()
# Out:
# OBJ: TH1D	CutFlow_VSI	 : 0 at: 0x7ffca5101d30

# %%
oldfile = ROOT.TFile('/data/newhouse/HNL/tests/histos_new/histograms_mc_ueu.root')
c = ROOT.TCanvas()
cutflow = oldfile.Get('VSI/CutFlow/CutFlow_VSI')
cutflow.ls()
c.SetLogy()
cutflow.SetFillColor(ROOT.kAzure-4)
cutflow.SetLineWidth(0)
cutflow.GetYaxis().SetTickLength(0.)
cutflow.SetMarkerSize(2.2)
cutflow.Draw('HIST TEXT35 SAME')
c.Draw()
# Out:
# OBJ: TH1D	CutFlow_VSI	 : 0 at: 0x7ffca630a790
