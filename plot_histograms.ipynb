# %%
import ROOT

# %%
oldfile = ROOT.TFile('/home/newhouse/public/Analysis/HNL/DHNLNtupleAnalysis/output_master/histograms_mc_ueu.root')
c = ROOT.TCanvas()
cutflow = oldfile.Get('VSI/CutFlow/CutFlow_VSI')
cutflow.ls()
c.SetLogy()
cutflow.SetFillColor(ROOT.kAzure-4)
cutflow.SetLineWidth(0)
cutflow.GetYaxis().SetTickLength(0.)
cutflow.SetMarkerSize(2.2)
cutflow.Draw('HIST TEXT35 SAME')
c.Draw()
# Out:
# OBJ: TH1D	CutFlow_VSI	 : 0 at: 0x7ffca696fb20

# %%
oldfile = ROOT.TFile('/home/newhouse/public/Analysis/HNL/DHNLNtupleAnalysis/output_newbranch/histograms_mc_ueu.root')
c = ROOT.TCanvas()
cutflow = oldfile.Get('VSI/CutFlow/CutFlow_VSI')
cutflow.ls()
c.SetLogy()
cutflow.SetFillColor(ROOT.kAzure-4)
cutflow.SetLineWidth(0)
cutflow.GetYaxis().SetTickLength(0.)
cutflow.SetMarkerSize(2.2)
cutflow.Draw('HIST TEXT35 SAME')
c.Draw()
# Out:
# OBJ: TH1D	CutFlow_VSI	 : 0 at: 0x7ffca6801720

# %%
oldfile = ROOT.TFile('/home/newhouse/public/Analysis/HNL/DHNLNtupleAnalysis/output_python3/histograms_mc_ueu.root')
c = ROOT.TCanvas()
cutflow = oldfile.Get('VSI/CutFlow/CutFlow_VSI')
cutflow.ls()
c.SetLogy()
cutflow.SetFillColor(ROOT.kAzure-4)
cutflow.SetLineWidth(0)
cutflow.GetYaxis().SetTickLength(0.)
cutflow.SetMarkerSize(2.2)
cutflow.Draw('HIST TEXT35 SAME')
c.Draw()
# Out:
# OBJ: TH1D	CutFlow_VSI	 : 0 at: 0x7ffca6970f50
