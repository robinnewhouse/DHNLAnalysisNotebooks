# %%
import uproot

old = uproot.open('/eos/home-r/rnewhous/tmp/mc16_13TeV.311602.Pythia8EvtGen_A14NNPDF23LO_WmuHNL50_3G_lt1dd.merge.NTUP_PILEUP.e7422_e5984_a875_r10740_r10706_p3384_p3385/NTUP_PILEUP.18059545._000002.pool.root')
new = uproot.open('/eos/home-r/rnewhous/tmp/mc16_13TeV.311602.Pythia8EvtGen_A14NNPDF23LO_WmuHNL50_3G_lt1dd.merge.NTUP_PILEUP.e7422_e5984_a875_r11915_r11748_p3604_p3605/NTUP_PILEUP.21476526._000001.pool.root')
central = uproot.open('/cvmfs/atlas.cern.ch/repo/sw/database/GroupData/dev/PileupReweighting/share/DSID311xxx/pileup_mc16a_dsid311602_AFII.root')

old['PileupReweighting']['pileup_chan311602_run284500'].show()
new['PileupReweighting']['pileup_chan311602_run284500'].show()
central['PileupReweighting']['pileup_chan311602_run284500'].show()
# Out:
#                0                                                           577.5
#                +---------------------------------------------------------------+
# [-inf, 0)  0   |                                                               |
# [0, 1)     0   |                                                               |
# [1, 2)     0   |                                                               |
# [2, 3)     0   |                                                               |
# [3, 4)     0   |                                                               |
# [4, 5)     10  |*                                                              |
# [5, 6)     10  |*                                                              |
# [6, 7)     10  |*                                                              |
# [7, 8)     10  |*                                                              |
# [8, 9)     10  |*                                                              |
# ...

# %%
print(old['PileupReweighting']['MCPileupReweighting'].pandas.df())
print('-----------------------------------------------------------')
print(new['PileupReweighting']['MCPileupReweighting'].pandas.df())
print('-----------------------------------------------------------')
print(central['PileupReweighting']['MCPileupReweighting'].pandas.df())
# Out:
#                 Channel  RunNumber  PeriodStarts  PeriodEnds  \
# entry subentry
# 0     0          311602     284500        222222      999999
#
#                                       HistName
# entry subentry
# 0     0         b'pileup_chan311602_run284500'
# -----------------------------------------------------------
#                 Channel  RunNumber  PeriodStarts  PeriodEnds  \
# entry subentry
# 0     0          311602     284500        222222      999999
#
#                                       HistName
# entry subentry
# 0     0         b'pileup_chan311602_run284500'
# -----------------------------------------------------------
#                 Channel  RunNumber  PeriodStarts  PeriodEnds  \
# entry subentry
# 0     0          311602     284500        222222      999999
# 1     0          311602     284500        222222      999999
# 2     0          311602     284500        222222      999999
# 3     0          311602     284500        222222      999999
# ...

# %%
import uproot

old = uproot.open('/eos/home-r/rnewhous/tmp/mc16_13TeV.311635.Pythia8EvtGen_A14NNPDF23LO_WmuHNL50_10G_lt1dd_el.merge.NTUP_PILEUP.e7422_e5984_a875_r10790_r10726_p3604_p3605/NTUP_PILEUP.18055731._000001.pool.root.1')
new = uproot.open('/eos/home-r/rnewhous/tmp/mc16_13TeV.311635.Pythia8EvtGen_A14NNPDF23LO_WmuHNL50_10G_lt1dd_el.merge.NTUP_PILEUP.e7422_e5984_a875_r11891_r11748_p3604_p3605/NTUP_PILEUP.21479601._000001.pool.root.1')
central = uproot.open('/cvmfs/atlas.cern.ch/repo/sw/database/GroupData/dev/PileupReweighting/share/DSID311xxx/pileup_mc16e_dsid311635_AFII.root')

old['PileupReweighting']['pileup_chan311635_run310000'].show()
new['PileupReweighting']['pileup_chan311635_run310000'].show()
central['PileupReweighting']['pileup_chan311635_run310000'].show()
# Out:
#                0                                                           640.5
#                +---------------------------------------------------------------+
# [-inf, 0)  0   |                                                               |
# [0, 1)     10  |*                                                              |
# [1, 2)     10  |*                                                              |
# [2, 3)     10  |*                                                              |
# [3, 4)     10  |*                                                              |
# [4, 5)     10  |*                                                              |
# [5, 6)     10  |*                                                              |
# [6, 7)     10  |*                                                              |
# [7, 8)     10  |*                                                              |
# [8, 9)     10  |*                                                              |
# ...

# %%
print(old['PileupReweighting']['MCPileupReweighting'].pandas.df())
print('-----------------------------------------------------------')
print(new['PileupReweighting']['MCPileupReweighting'].pandas.df())
print('-----------------------------------------------------------')
print(central['PileupReweighting']['MCPileupReweighting'].pandas.df())
# Out:
#                 Channel  RunNumber  PeriodStarts  PeriodEnds  \
# entry subentry
# 0     0          311635     310000        222222      999999
# 1     0          311635     310000        222222      999999
#
#                                       HistName
# entry subentry
# 0     0         b'pileup_chan311635_run310000'
# 1     0         b'pileup_chan311635_run310000'
# -----------------------------------------------------------
#                 Channel  RunNumber  PeriodStarts  PeriodEnds  \
# entry subentry
# 0     0          311635     310000        222222      999999
#
#                                       HistName
# entry subentry
# 0     0         b'pileup_chan311635_run310000'
# -----------------------------------------------------------
#                 Channel  RunNumber  PeriodStarts  PeriodEnds  \
# entry subentry
# 0     0          311635     310000        222222      999999
#
#                                       HistName
# entry subentry
# ...
